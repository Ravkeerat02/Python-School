# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravkeerat02/py_labs/blob/main/Week_04_How_to_define_and_use_functions_and_modules_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Audio Only ............................... With Video
#
# ![01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def my_average(total, num):
  x = total/num
  return x

# %%
my_average(24,6)
# Out:
# 4.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_welcome():
  print("Welcome to the Future Value Calculator")
  print()

# %%
print_welcome()
# Out:
# Welcome to the Future Value Calculator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_welcome(message):
  print(message)
  print()

# %%
myMessage = "Welcome to the Future Value Calculator"

# %%
print_welcome(myMessage)
# Out:
# Welcome to the Future Value Calculator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def calculate_miles_per_gallon(miles_driven, gallons):
    mpg = miles_driven / gallons
    mpg = round(mpg, 1)
    return mpg

# %%
miles = 500
gallons = 14
mpg = calculate_miles_per_gallon(miles, gallons)	# 35.7

# %%
mpg
# Out:
# 35.7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def some_function(first_param, second_param = 10):
		return first_param + second_param

# %%
some_function(5, 4)
# Out:
# 9

# %%
some_function(5)
# Out:
# 15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The above code brings some errors and needs some modifications....

# %%
def calc_tax(x):
  x = x * 0.08
  return x

# %%
def add_shipping(subtot):
  subtot = float(subtot) * 1.04
  return subtot

# %%
def main():
  units = input("Please enter the # of units")
  firstTotal = float(units) * 5.0
  total = add_shipping(firstTotal)
  total = total + calc_tax(total)
  print("Your total is: ", total)

# %%
main()
# Out:
# Please enter the # of units10
# Your total is:  56.16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def square(x):
  return x * x

# %%
square(5)
# Out:
# 25

# %%
myOutput=square(10)

# %%
myOutput
# Out:
# 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def hi_low(x,y):
  if(x >= y):
    return x, y
  else:
    return y, x

# %%
hi_low(20,30)
# Out:
# (30, 20)

# %%
hi_low(100,50)
# Out:
# (100, 50)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sample_variable = 123
MY_CONSTANT = "time"
print(sample_variable)
# Out:
# 123

# %%
def my_func(param):  
  global sample_variable
  print("Global variable before change:")
  print(sample_variable)
  sample_variable = 987
  print("Global variable after change:")
  print(sample_variable)
  return MY_CONSTANT + ' '  + param

# %%
print(my_func("never ends"))
# Out:
# Global variable before change:
# 123
# Global variable after change:
# 987
# time never ends

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import my_calc_square

# %%
my_calc_square.calc_square(10)
# Out:
# 100

# %%
from my_calc_square import calc_square

# %%
calc_square(5)
# Out:
# 25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def my_add(value1, value2):
    """Calculate the sum of value1 and value2."""
    return value1 + value2

# %%
my_add.__doc__
# Out:
# 'Calculate the sum of value1 and value2.'

# %%
help(my_add)
# Out:
# Help on function my_add in module __main__:
#
# my_add(value1, value2)
#     Calculate the sum of value1 and value2.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def calc_tax(x):
  x = x * 0.08
  return x

# %%
def add_shipping(subtot):
  subtot = float(subtot) * 1.04
  return subtot

# %%
def main():
  units = input("Please enter the # of units: ")
  firstTotal = float(units) * 5.0
  total = add_shipping(firstTotal)
  total = total + calc_tax(total)
  print("Your total is: ", total)

# %%
main()
# Out:
# Please enter the # of units: 10
# Your total is:  56.16

# %%
if __name__ == "__main__":  # if main module
    main()			        # call main() function
# Out:
# Please enter the # of units: 10
# Your total is:  56.16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_4',
#  '_6',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'add',
#  'add_shipping',
#  'calc_square',
#  'calc_tax',
#  'exit',
#  'get_ipython',
#  'main',
#  'my_add',
#  'my_calc_square',
#  'quit']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
vec = [1, 2, 3]
result = [[x + 1, x * 2] for x in vec]
print(result)
# Out:
# [[2, 2], [3, 4], [4, 6]]

# %%
bool(14%2)
# Out:
# False
