# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravkeerat02/py_labs/blob/main/wk4_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the random library to use for the dice later

#student name - Ravkeerat Singh 
#SID - 101344680
import random

def use_loot(first_item, health_points):
    print(" --- You see a monster in the distance! So you quickly use your first item.")
    first_item = belt.pop(0)
    if first_item in good_loot_options:
        health_points = min(6, (health_points + 2))
        print("You used " + first_item +  " to up your health to:  " + str(health_points))
    elif first_item in bad_loot_options:
        health_points = max(0, (health_points - 2))
        print("You used " + first_item +  " to reduce your health to:  " + str(health_points))
    else:
        print("You used " + first_item + " but it aint of usee")
        return [first_item, health_points]

# Lab 4: Hero's Attack Functions
def hero_attacks(combat_strength, m_health_points):
    ascii_image = """
                                @@   @@ 
                                @    @  
                                @   @   
               @@@@@@          @@  @    
            @@       @@        @ @@     
           @%         @     @@@ @       
            @        @@     @@@@@     
               @@@@@        @@       
               @    @@@@                
          @@@ @@                        
       @@     @                         
   @@*       @                          
   @        @@                          
           @@                                                    
         @   @@@@@@@                    
        @            @                  
      @              @                  

  """
    print(ascii_image)
    print("Player's weapon (" + str(combat_strength) + ") ---> Monster (" + str(m_health_points) + ")")
    if combat_strength >= m_health_points:
        # Player was strong enough to kill monster in one blow
        m_health_points = 0
        print("You have killed the monster")
    else:
        # Player only damaged the monster
        m_health_points -= combat_strength

        print("You have reduced the monster's health to: " + str(m_health_points))
    return m_health_points


# Lab 4: Monster's Attack Function
def monster_attacks(m_combat_strength, health_points):
    ascii_image2 = """                                                                 
   @@@@ @                           
      (     @*&@  ,                         
    @               %                       
     &#(@(@%@@@@@*   /                      
      @@@@@.                                
               @       /                    
                %         @                 
            ,(@(*/           %              
               @ (  .@#                 @   
                          @           .@@. @
                   @         ,              
                      @       @ .@          
                             @              
                          *(*  *       
             """
    print(ascii_image2)
    print("Monster's Claw (" + str(m_combat_strength) + ") ---> Player (" + str(health_points) + ")")
    if m_combat_strength >= health_points:
        # Monster was strong enough to kill player in one blow
        health_points = 0
        print("Player is dead")
    else:
        # Monster only damaged the player
        health_points -= m_combat_strength
        print("The monster has reduced Player's health to: " + str(health_points))
    return health_points


# Game
# Define The number of lives for the Hero and Monster
numLives = 10  # number of player's lives remaining
mNumLives = 12  # number of monster's lives remaining

# Lab 3: Answer 1: Define the Dice
diceOptions = list(range(1, 7))
# Define the Weapons
weapons = ["Fist", "Knife", "Club", "Gun", "Bomb", "Nuclear Bomb"]

# Lab 3: Answer 2: Print out the weapons using a for loop
for weapon in weapons:
    print(weapon)

# Define the Loot
loot_options = ["Health Potion", "Poison Potion", "Secret Note", "Leather Boots", "Flimsy Gloves"]
good_loot_options = ["Health Potion", "Leather Boots"]
bad_loot_options = ["Poison Potion"]
belt = []

# Define the Monster's Powers
monster_powers = {
    "Fire Magic": 2,
    "Freeze Time": 4,
    "Super Hearing": 6
}

# Loop to get valid input for Hero and Monster's Combat Strength
i = 0
while i in range(5):
    combat_strength = input("Enter your combat Strength (1-6): ")
    m_combat_strength = input("Enter the monster's combat Strength (1-6): ")

    # Validate input: Check if the string inputted is numeric
    if (not combat_strength.isnumeric()) or (not m_combat_strength.isnumeric()):
        # If one of the inputs are invalid, print error message and halt
        print("One or more invalid inputs. Player needs to enter integer numbers for Combat Strength")
        i = i + 1
        continue

    # Note: Now safe to cast combat_strength to integer
    # Lab 3: Answer 3 : Validate input: Check if the string inputted
    elif (int(combat_strength) not in range(1, 7)) or (int(m_combat_strength)) not in range(1, 7):
        print("Enter a valid integer between 1 and 6 only")
        i = i + 1
        continue

    else:
        break

# Input was valid - broke out of while lop
inputInvalid = False
combat_strength = int(combat_strength)
m_combat_strength = int(m_combat_strength)

# Roll for weapon
input("Roll the dice for your weapon (Press enter)")
weaponRoll = random.choice(diceOptions)

# Max out the combat strength at 6
combat_strength = min(6, (combat_strength + weaponRoll))
print("The hero\'s weapon is " + str(weapons[weaponRoll - 1]))

# Weapon Roll Analysis
input("Analyze the Weapon roll (Press enter)")
if weaponRoll <= 2:
    print("--- You rolled a weak weapon, friend")
elif weaponRoll <= 4:
    print("--- Your weapon is meh")
else:
    print("--- Nice weapon, friend!")

# If the weapon rolled is not a Fist, print out "Thank goodness you didn't roll the Fist..."
if weapons[weaponRoll - 1] != "Fist":
    print("--- Thank goodness you didn't roll the Fist...")

# Roll for player health points
input("Roll the dice for your health points (Press enter)")
health_points = random.choice(diceOptions)
print("Player rolled " + str(health_points) + " health points")

# Roll for monster health points
input("Roll the dice for the monster's health points (Press enter)")
m_health_points = random.choice(diceOptions)
print("Player rolled " + str(m_health_points) + " health points for the monster")

# Collect Loot
def collect_loot(lootRoll , loot):
    print("!!You find a loot bag!! You look inside to find 2 items:")
    input("Roll for first item (enter)")
    lootRoll = random.choice(range(1, len(loot_options) + 1))
    loot = loot_options.pop(lootRoll - 1)
    belt.append(loot)
    print("Your belt: ", belt)
    return belt

# Second Collect Loot
def second_loot(lootRoll,loot):
    input("Roll for second item (Press enter)")
    lootRoll = random.choice(range(1, len(loot_options) + 1))
    loot = loot_options.pop(lootRoll - 1)
    belt.append(loot)
    print("Your belt: ", belt)
    return belt

print("Your belt contains: " + str(belt))

belt = collect_loot('loot_roll', 'loot')
belt = use_loot('first_item', 'health_points')

# Organize Belt
print("You're super neat, so you organize your belt alphabetically:")
belt.sort()
print("Your belt: ", belt)

# Lab 3: Collect Loot
print(" --- You find a loot bag! You look inside to find 2 items: ")
input("Roll for first item (Press Enter")
loot_roll = random.choice(range(1, len(loot_options) + 1))
loot = loot_options.pop(loot_roll - 1)
belt.append(loot) 
print("Your belt contains: " + str(belt))

# Collect second loot
input("Roll for second item (Press Enter)")
loot_roll = random.choice(range(1, len(loot_options) + 1))
loot = loot_options.pop(loot_roll - 1)
belt.append(loot)
print("Your belt contains: " + str(belt))

# Use Loot
print("!!You see a monster in the distance! So you quickly use your first item:")
if belt:
  first_item = belt.pop(0)
  if first_item in good_loot_options:
      health_points = min(6, (health_points + 2))
      print("You used " + first_item + " to up your health to " + str(health_points))
  elif first_item in bad_loot_options:
      health_points = max(0, (health_points - 2))
      print("You used " + first_item + " to hurt your health to " + str(health_points))
  else:
      print("You used " + first_item + " but it's not helpful")

input("Analyze the roll (Press enter)")
# Compare Player vs Monster's strength
print("--- You are matched in strength: " + str(combat_strength == m_combat_strength))

# Check the Player's overall strength and health
print("--- You have a strong player: " + str((combat_strength + health_points) >= 15))

# Lab 4: Roll for the monster's power
input("Roll for Monster's Magic Power (Press enter)")
power_roll = random.choice(["Fire Magic", "Freeze Time", "Super Hearing"])

# Lab 4: Increase the monster’s combat strength by its power
m_combat_strength += min(6, monster_powers[power_roll])
print("The monster's combat strength is now " + str(m_combat_strength) + " using the " + power_roll + " magic power")

# Lab 3: Answer 4
# for j in range(1, 20, 2):
#   Fight Sequence
# ...
#   if j == 11:
#       break

# Lab 4: Loop while the monster and the player are alive. Call fight sequence functions
print("You meet the monster. FIGHT!!")
while m_health_points > 0 and health_points > 0:
    # Fight Sequence
    input("You strike first (Press enter)")
    m_health_points = hero_attacks(combat_strength, m_health_points)
    if m_health_points == 0:
        num_stars = 3
    else:
        input("The monster strikes (Press enter)!!!")
        health_points = monster_attacks(m_combat_strength, health_points)
        if health_points == 0:
            num_stars = 1
            break
        else:
            num_stars = 2
            continue


stars = "*" * num_stars
#task 1
hero_name = (input('Enter the name: '))
# task 1B 
hero_name = input("Please enter a name")
short = hero_name.split(" ")
short_name = short[0][:2] + short[1][:1] 
print("Hero gets <" + stars + "> stars")


#task 4 
attack_roll = random.randint(1,7)
if attack_roll == 1 or attack_roll == 3 or attack_roll == 5:
  print("Hero goes 1st")
else :
  print("Monster goes 1st")
# Out:
# Fist
# Knife
# Club
# Gun
# Bomb
# Nuclear Bomb
# Enter your combat Strength (1-6): 4
# Enter the monster's combat Strength (1-6): 5
# Roll the dice for your weapon (Press enter)
# The hero's weapon is Club
# Analyze the Weapon roll (Press enter)
# --- Your weapon is meh
# --- Thank goodness you didn't roll the Fist...
# Roll the dice for your health points (Press enter)
# Player rolled 1 health points
# Roll the dice for the monster's health points (Press enter)
# Player rolled 1 health points for the monster
# Your belt contains: []
# !!You find a loot bag!! You look inside to find 2 items:
# Roll for first item (enter)
# Your belt:  ['Poison Potion']
#  --- You see a monster in the distance! So you quickly use your first item.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-abdbd17b716a> in <module>()
#     193
# ...

# %%
# Import the random library to use for the dice later
import random


def use_loot(first_item, health_points):
    print(" --- You see a monster in the distance! So you quickly use your first item.")
    first_item = belt.pop(0)
    if first_item in good_loot_options:
        health_points = min(6, (health_points + 2))
        print("You used " + first_item +  " to up your health to " + str(health_points))
    elif first_item in bad_loot_options:
        health_points = max(0, (health_points - 2))
        print("You used " + first_item +  " to reduce your health to " + str(health_points))
    else:
        print("You used " + first_item + " but it is not helpful")
        return [first_item, health_points]


# Lab 4 Hero's attack function
def hero_attacks(combat_strength, m_health_points):
    ascii_image = """
                                    @@   @@ 
                                    @    @  
                                    @   @   
                   @@@@@@          @@  @    
                @@       @@        @ @@     
               @%         @     @@@ @       
                @        @@     @@@@@     
                   @@@@@        @@       
                   @    @@@@                
              @@@ @@                        
           @@     @                         
       @@*       @                          
       @        @@                          
               @@                                                    
             @   @@@@@@@                    
            @            @                  
          @              @                  

      """
    print(ascii_image)
    print("Your sword (" + str(combat_strength) + ") ---> Monster (" + str(m_health_points) + ")")
    if combat_strength >= m_health_points:
        # Player was strong enough to kill monster in one blow
        m_health_points = 0
        print("You have killed the monster")
    else:
        # Player only damaged the monster
        m_health_points -= combat_strength
        print("You have reduced the monster's health to: " + str(m_health_points))


# Lab 4 monster's attack function
def monster_attacks(m_combat_strength, health_points):

        ascii_Image2 = """                                                                 
           @@@@ @                           
      (     @*&@  ,                         
    @               %                       
     &#(@(@%@@@@@*   /                      
      @@@@@.                                
               @       /                    
                %         @                 
            ,(@(*/           %              
               @ (  .@#                 @   
                          @           .@@. @
                   @         ,              
                      @       @ .@          
                             @              
                          *(*  *      
             """

        print(ascii_Image2)
        print("The monster strikes!!")
        print("Monster's Claw (" + str(m_combat_strength) + ") ---> Hero (" + str(health_points) + ")")
    
        if m_combat_strength >= health_points:
            # Monster was strong enough to kill player in one blow
            health_points = 0
            print("You're dead.")
        else:
            # Monster only damaged the player
            health_points -= m_combat_strength
            print("The monster has reduced your health to: " + str(health_points))
        return health_points

# Game Flow

# Define Variable
num_lives = 10       # Number of player's lives remaining
m_num_lives = 12      # Number of monster's lives remaining

# Define the dice  # Lab 3 Q1
dice_options = list(range(1, 7))                                            

# Lab 2 Answer: 1. Define the Weapons
weapons = ["Fist", "Knife", "Club", "Gun", "Bomb", "Nuclear Bomb"]          

# Lab 3 Q2
input("Here is the weapon list. Are you feeling lucky? (Press Enter)")
for weapons in weapons:
    print(" --- " + weapons)

# Lab 3: Define the loot
loot_options = ["Health Potion", "Mysterious Potion", "Secret Note", "Leather Boots", "Flimsy Gloves"]
good_loot_options = ["Health Potion", "Leather Boots"]
bad_loot_options = ["Mysterious Potion"]
belt = []

# Define the Monster's powers
monster_powers = {
    "Fire Magic": 2,
    "Freeze Time": 4,
    "Super Hearing": 6
}

# Lab 3: Loop to get the valid input for Hero and Monster's Combat Strength
i = 0
while i in range(5):
    combat_strength = input("Enter your combat Strength (1-6): ")
    m_combat_strength = input("Enter the monster's combat Strength (1-6): ")

    # Validate input: Check if the string inputted is numeric
    if (not combat_strength.isnumeric()) or (not m_combat_strength.isnumeric()):
        # If one of the inputs are invalid, print error message and halt
        print("One or more invalid inputs. Player needs to enter integer numbers for Combat Strength")
        i = i + 1
        continue

    # Note: Now safe to cast combat_strength to integer
    # Lab 3: Answer 3 : Validate input: Check if the string inputted
    elif (int(combat_strength) not in range(1, 7)) or (int(m_combat_strength)) not in range(1, 7):
        print("Enter a valid integer between 1 and 6 only")
        i = i + 1
        continue
    else:
        break

# Lab 3: Input was Valid
input_invalid = False
combat_strength = int(combat_strength)
m_combat_strength = int(m_combat_strength)

# Lab 2 Answer: 2. Roll for weapon
input("Role the dice to your weapon (Press enter): ")                      
weapon_roll = random.choice(dice_options)                                  

# Max out the combat strength 6
combat_strength = min(6,(combat_strength + weapon_roll))                   
#print("You rolled: " + str(weapon_roll))
print("Your combat strength is: " + str(combat_strength))
print("Your weapon is: " + str(weapons[weapon_roll - 1]))                  



# Lab 2 Answer: 3. Weapon Roll Analysis
input("Analyze the Weapon roll (Press enter)")
if weapon_roll <= 2:
    print("--- You rolled a weak weapon, friend")
elif weapon_roll <= 4:
    print("--- Your weapon is meh")
else:
    print("--- Nice weapon, friend!")

# Lab 2 Answer: 4. If the weapon rolled is not a Fist, print out "Thank goodness you didn't roll the Fist..."
if weapon_roll != 1:                                                        
    print("You are lucky you didn't get the fist.")                         
else:                                                                       
    print("Ohhh boy. Tough luck. You got the fist")                         

# Roll for player health points
input("Roll the dice for your health point (Press enter)")
health_points = random.choice(dice_options)
print("You rolled " + str(health_points) + " health points.")

# Roll for monster health points
input("Roll the dice for your monster's health point (Press enter)")
m_health_points = random.choice(dice_options)
print("You rolled " + str(m_health_points) + " health points for the monster.")

# Roll for healing potion
input("Roll the dice to see if you find a healing potion. (Press enter)")
healing_potion = random.choice([0, 1])
print("Have you found a healing potion: " + str(bool(healing_potion)))

def collect_loot(loot_roll, loot):
    # Lab 3: Collect Loot
    print(" --- You find a loot bag! You look inside to find 2 items: ")
    input("Roll for first item (Press Enter")
    loot_roll = random.choice(range(1, len(loot_options) + 1))
    loot = loot_options.pop(loot_roll - 1)
    belt.append(loot)  
    print("Your first loot is: " + loot)
    return belt

# Collect second loot
def second_loot(loot_roll, loot):
    input("Roll for second item (Press Enter)")
    loot_roll = random.choice(range(1, len(loot_options) + 1))
    loot = loot_options.pop(loot_roll - 1)
    belt.append(loot)
    print("Your second loot is: " + loot)
    return belt

print("Your belt contains: " + str(belt))

belt = collect_loot('loot_roll', 'loot')
belt = use_loot('first_item', 'health_points')


# Organise belt
print("You are super neat, so you organize your belt aplhabetically. ")
belt.sort()
print("Your belt contains: " + str(belt)) 

# Lab 3: Collect Loot
print(" --- You find a loot bag! You look inside to find 2 items: ")
input("Roll for first item (Press Enter")
loot_roll = random.choice(range(1, len(loot_options) + 1))
loot = loot_options.pop(loot_roll - 1)
belt.append(loot) 
print("Your belt contains: " + str(belt))

# Collect second loot
input("Roll for second item (Press Enter)")
loot_roll = random.choice(range(1, len(loot_options) + 1))
loot = loot_options.pop(loot_roll - 1)
belt.append(loot)
print("Your belt contains: " + str(belt))

# Lab 3: Use loot
print(" --- You see a monster in the distance! So you quickly use your first item.")
first_item = belt.pop(0)
if first_item in good_loot_options:
    health_points = min(6, (health_points + 2))
    print("You used " + first_item +  " to up your health to " + str(health_points))
elif first_item in bad_loot_options:
    health_points = max(0, (health_points - 2))
    print("You used " + first_item +  " to reduce your health to " + str(health_points))
else:
    print("You used " + first_item + " but it is not helpful")
    
input("Analyze the roll (Press enter)")
# Equality operators # Compare Player vs Monster's strength
print(" --- You are matched in strength: " + str(combat_strength == m_combat_strength))

# Relational operator # Check the Player's overall strength and health
print(" --- You have a strong player: " + str((combat_strength + health_points) >= 15))

# Lab 4 Roll for the monster's power
input("Roll for Monster's Magic Power (Press Enter)")
power_roll = random.choice(list(monster_powers.keys()))

# Lab 4 Increase the monster's combat strength by its power
m_combat_strength = min(6,m_combat_strength + monster_powers[power_roll])
print("The Monster's combat strength is " + str(m_combat_strength) + " using the " + power_roll + " magic power.")

# and keyword
print(" --- Remember to take a healing potion: " + str(healing_potion == 1 and health_points < 6))

# not keyword
print(" --- Let's see if your healing potion can help you: " + str(not(health_points < m_combat_strength) and healing_potion))

# or keyword
print(" --- Things getting dangerous: " + str(healing_potion is False or health_points == 0))

# in keyword
print(" --- Is it possible to roll 0 in the dice? " + str(0 in dice_options))

# Expanded if statement
if health_points >= 5:
    print("Your health is ok")
elif healing_potion:
    healing_potion = False
    health_points = 6
    print(" --- Using your health potion now... Your health points are at  " + str(health_points))
else:
    print(" --- Your health is low at " + str(health_points) + " and you have no healing potion available")

# Nested if statement # Fight Sequence
print("You meet the monster. FIGHT!!!")

# Lab 4 Loop while the mosnter and the player are alive. Call fight sequence function
attack_roll = random.randint(1, 7)
while m_health_points > 0 and health_points > 0:
    if attack_roll % 2 == 1:
        print("Monster strikes first.")
        health_points = monster_attacks(m_combat_strength, health_points)
        if health_points == 0:
            num_starts = 1
            break
        else:
            num_starts = 2

        print("Hero strikes first.")
        m_health_points = hero_attacks(combat_strength, m_health_points)
        if m_health_points == 0:
            num_starts = 3
            break
        else:
            # Define the number of starts awarded to the Player
            num_starts = 0   

stars = "*" * num_starts

hero_name = input("Enter Hero's first and last name using space: ")
s_name = hero_name.split(" ")
short_name = s_name[0][:2] + s_name[1][:1]
print("Hero ",  short_name, " gets <", stars, "> stars")
# Out:
#  --- Fist
#  --- Knife
#  --- Club
#  --- Gun
#  --- Bomb
#  --- Nuclear Bomb
# Your combat strength is: 6
# Your weapon is: c
# --- Your weapon is meh
# You are lucky you didn't get the fist.
# You rolled 2 health points.
# You rolled 4 health points for the monster.
# Have you found a healing potion: True
# Your belt contains: []
#  --- You find a loot bag! You look inside to find 2 items:
# Your first loot is: Secret Note
#  --- You see a monster in the distance! So you quickly use your first item.
# You used Secret Note but it is not helpful
# You are super neat, so you organize your belt aplhabetically.
# Your belt contains: ['Secret Note', 'health_points']
#  --- You find a loot bag! You look inside to find 2 items:
# Your belt contains: ['Secret Note', 'health_points', 'Leather Boots']
# Your belt contains: ['Secret Note', 'health_points', 'Leather Boots', 'Mysterious Potion']
#  --- You see a monster in the distance! So you quickly use your first item.
# ...
